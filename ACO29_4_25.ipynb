# %% [markdown]
# <a href="https://colab.research.google.com/github/Mukundatgit/B9IS109_2324_TMD2/blob/main/ACO29_4_25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install numpy==1.24
# Out:
# Requirement already satisfied: numpy==1.24 in /usr/local/lib/python3.11/dist-packages (1.24.0)

# %%
# !pip install mealpy
# Out:
# Requirement already satisfied: mealpy in /usr/local/lib/python3.11/dist-packages (3.0.1)
# Requirement already satisfied: numpy>=1.17.5 in /usr/local/lib/python3.11/dist-packages (from mealpy) (1.24.0)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from mealpy) (3.10.0)
# Requirement already satisfied: scipy>=1.7.1 in /usr/local/lib/python3.11/dist-packages (from mealpy) (1.15.2)
# Requirement already satisfied: pandas>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from mealpy) (2.2.2)
# Requirement already satisfied: opfunu>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from mealpy) (1.0.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->mealpy) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->mealpy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->mealpy) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->mealpy) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->mealpy) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->mealpy) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->mealpy) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->mealpy) (2.9.0.post0)
# Requirement already satisfied: requests>=2.27.0 in /usr/local/lib/python3.11/dist-packages (from opfunu>=1.0.0->mealpy) (2.32.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2.0->mealpy) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2.0->mealpy) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->mealpy) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.27.0->opfunu>=1.0.0->mealpy) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.27.0->opfunu>=1.0.0->mealpy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.27.0->opfunu>=1.0.0->mealpy) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.27.0->opfunu>=1.0.0->mealpy) (2025.1.31)

# %%
import json
from mealpy import FloatVar
from mealpy.swarm_based import *
import time
import numpy as np

# %%
def Fun(solution):
  list1 = [0] * data['vmcount'][0]
  val = 0.0
  #print(solution)
  #print(int(round(solution[0])))
  for i in range(solution.size):
    solution[i]=round(solution[i])
    if(round(solution[i])!=0.0):
      list1[int(round(solution[i]))-1]=list1[int(round(solution[i]))-1] + data['task'][0]/data['VM'][int(round(solution[i]))-1]
    else:
      list1[int(round(solution[i]))]=list1[int(round(solution[i]))-1] + data['task'][0]/data['VM'][int(round(solution[i]))]
  #print(solution)
  return min(list1)

# %%
f = open('/content/data.json')
data = json.load(f)
size = data['tcount'][0]
vmcount = data['vmcount'][0]

problem_dict = {
    "bounds": FloatVar(lb=[0 for i in range(size)], ub=[vmcount for i in range(size)], name="delta"),
    "obj_func": Fun,
    "minmax": "min",
    "verbose": True,
}

print("Task Count is set to", size)
print("VM Count is set to", vmcount)

start_time = time.time()
model = ACOR.OriginalACOR(epoch=100, pop_size=50, sample_count=25, intent_factor=0.5, zeta=1.0)

g_best = model.solve(problem_dict)

end_time = time.time()
print(f"Solution: {g_best.solution}, Fitness: {g_best.target.fitness}")
print(f"Solution: {model.g_best.solution}, Fitness: {model.g_best.target.fitness}")
# Out:
# INFO:mealpy.swarm_based.ACOR.OriginalACOR:Solving single objective optimization problem.
# INFO:mealpy.swarm_based.ACOR.OriginalACOR:>>>Problem: P, Epoch: 1, Current best: 0.0, Global best: 0.0, Runtime: 0.14638 seconds
# Task Count is set to 40
# VM Count is set to 10
# INFO:mealpy.swarm_based.ACOR.OriginalACOR:>>>Problem: P, Epoch: 2, Current best: 0.0, Global best: 0.0, Runtime: 0.19690 seconds
# INFO:mealpy.swarm_based.ACOR.OriginalACOR:>>>Problem: P, Epoch: 3, Current best: 0.0, Global best: 0.0, Runtime: 0.25748 seconds
# INFO:mealpy.swarm_based.ACOR.OriginalACOR:>>>Problem: P, Epoch: 4, Current best: 0.0, Global best: 0.0, Runtime: 0.15927 seconds
# INFO:mealpy.swarm_based.ACOR.OriginalACOR:>>>Problem: P, Epoch: 5, Current best: 0.0, Global best: 0.0, Runtime: 0.18353 seconds
# INFO:mealpy.swarm_based.ACOR.OriginalACOR:>>>Problem: P, Epoch: 6, Current best: 0.0, Global best: 0.0, Runtime: 0.23708 seconds
# INFO:mealpy.swarm_based.ACOR.OriginalACOR:>>>Problem: P, Epoch: 7, Current best: 0.0, Global best: 0.0, Runtime: 0.15466 seconds
# INFO:mealpy.swarm_based.ACOR.OriginalACOR:>>>Problem: P, Epoch: 8, Current best: 0.0, Global best: 0.0, Runtime: 0.10003 seconds
# INFO:mealpy.swarm_based.ACOR.OriginalACOR:>>>Problem: P, Epoch: 9, Current best: 0.0, Global best: 0.0, Runtime: 0.08121 seconds
# INFO:mealpy.swarm_based.ACOR.OriginalACOR:>>>Problem: P, Epoch: 10, Current best: 0.0, Global best: 0.0, Runtime: 0.08376 seconds
# INFO:mealpy.swarm_based.ACOR.OriginalACOR:>>>Problem: P, Epoch: 11, Current best: 0.0, Global best: 0.0, Runtime: 0.08581 seconds
# INFO:mealpy.swarm_based.ACOR.OriginalACOR:>>>Problem: P, Epoch: 12, Current best: 0.0, Global best: 0.0, Runtime: 0.09438 seconds
# INFO:mealpy.swarm_based.ACOR.OriginalACOR:>>>Problem: P, Epoch: 13, Current best: 0.0, Global best: 0.0, Runtime: 0.08768 seconds
# INFO:mealpy.swarm_based.ACOR.OriginalACOR:>>>Problem: P, Epoch: 14, Current best: 0.0, Global best: 0.0, Runtime: 0.11655 seconds
# INFO:mealpy.swarm_based.ACOR.OriginalACOR:>>>Problem: P, Epoch: 15, Current best: 0.0, Global best: 0.0, Runtime: 0.09555 seconds
# INFO:mealpy.swarm_based.ACOR.OriginalACOR:>>>Problem: P, Epoch: 16, Current best: 0.0, Global best: 0.0, Runtime: 0.12072 seconds
# INFO:mealpy.swarm_based.ACOR.OriginalACOR:>>>Problem: P, Epoch: 17, Current best: 0.0, Global best: 0.0, Runtime: 0.16713 seconds
# INFO:mealpy.swarm_based.ACOR.OriginalACOR:>>>Problem: P, Epoch: 18, Current best: 0.0, Global best: 0.0, Runtime: 0.26905 seconds
# INFO:mealpy.swarm_based.ACOR.OriginalACOR:>>>Problem: P, Epoch: 19, Current best: 0.0, Global best: 0.0, Runtime: 0.49455 seconds
# INFO:mealpy.swarm_based.ACOR.OriginalACOR:>>>Problem: P, Epoch:
seconds
# INFO:mealpy.swarm_based.ACOR.OriginalACOR:>>>Problem: P, Epoch: 70, Current best: 0.0, Global best: 0.0, Runtime: 0.09466 seconds
# INFO:mealpy.swarm_based.ACOR.OriginalACOR:>>>Problem: P, Epoch: 71, Current best: 0.0, Global best: 0.0, Runtime: 0.09382 seconds
# INFO:mealpy.swarm_based.ACOR.OriginalACOR:>>>Problem: P, Epoch: 72, Current best: 0.0, Global best: 0.0, Runtime: 0.08348 seconds
# INFO:mealpy.swarm_based.ACOR.OriginalACOR:>>>Problem: P, Epoch: 73, Current best: 0.0, Global best: 0.0, Runtime: 0.09329 seconds
# INFO:mealpy.swarm_based.ACOR.OriginalACOR:>>>Problem: P, Epoch: 74, Current best: 0.0, Global best: 0.0, Runtime: 0.08731 seconds
# INFO:mealpy.swarm_based.ACOR.OriginalACOR:>>>Problem: P, Epoch: 75, Current best: 0.0, Global best: 0.0, Runtime: 0.08243 seconds
# INFO:mealpy.swarm_based.ACOR.OriginalACOR:>>>Problem: P, Epoch: 76, Current best: 0.0, Global best: 0.0, Runtime: 0.08810 seconds
# INFO:mealpy.swarm_based.ACOR.OriginalACOR:>>>Problem: P, Epoch: 77, Current best: 0.0, Global best: 0.0, Runtime: 0.08542 seconds
# INFO:mealpy.swarm_based.ACOR.OriginalACOR:>>>Problem: P, Epoch: 78, Current best: 0.0, Global best: 0.0, Runtime: 0.08400 seconds
# INFO:mealpy.swarm_based.ACOR.OriginalACOR:>>>Problem: P, Epoch: 79, Current best: 0.0, Global best: 0.0, Runtime: 0.12235 seconds
# INFO:mealpy.swarm_based.ACOR.OriginalACOR:>>>Problem: P, Epoch: 80, Current best: 0.0, Global best: 0.0, Runtime: 0.09334 seconds
# INFO:mealpy.swarm_based.ACOR.OriginalACOR:>>>Problem: P, Epoch: 81, Current best: 0.0, Global best: 0.0, Runtime: 0.08917 seconds
# INFO:mealpy.swarm_based.ACOR.OriginalACOR:>>>Problem: P, Epoch: 82, Current best: 0.0, Global best: 0.0, Runtime: 0.09398 seconds
# INFO:mealpy.swarm_based.ACOR.OriginalACOR:>>>Problem: P, Epoch: 83, Current best: 0.0, Global best: 0.0, Runtime: 0.10037 seconds
# INFO:mealpy.swarm_based.ACOR.OriginalACOR:>>>Problem: P, Epoch: 84, Current best: 0.0, Global best: 0.0, Runtime: 0.08918 seconds
# INFO:mealpy.swarm_based.ACOR.OriginalACOR:>>>Problem: P, Epoch: 85, Current best: 0.0, Global best: 0.0, Runtime: 0.08905 seconds
# INFO:mealpy.swarm_based.ACOR.OriginalACOR:>>>Problem: P, Epoch: 86, Current best: 0.0, Global best: 0.0, Runtime: 0.09265 seconds
# INFO:mealpy.swarm_based.ACOR.OriginalACOR:>>>Problem: P, Epoch: 87, Current best: 0.0, Global best: 0.0, Runtime: 0.08937 seconds
# INFO:mealpy.swarm_based.ACOR.OriginalACOR:>>>Problem: P, Epoch: 88, Current best: 0.0, Global best: 0.0, Runtime: 0.08692 seconds
# INFO:mealpy.swarm_based.ACOR.OriginalACOR:>>>Problem: P, Epoch: 89, Current best: 0.0, Global best: 0.0, Runtime: 0.10786 seconds
# INFO:mealpy.swarm_based.ACOR.OriginalACOR:>>>Problem: P, Epoch: 90, Current best: 0.0, Global best: 0.0, Runtime: 0.10100 seconds
# INFO:mealpy.swarm_based.ACOR.OriginalACOR:>>>Problem: P, Epoch: 91, Current best: 0.0, Global best: 0.0, Runtime: 0.09070 seconds
# INFO:mealpy.swarm_based.ACOR.OriginalACOR:>>>Problem: P, Epoch: 92, Current best: 0.0, Global best: 0.0, Runtime: 0.10426 seconds
# INFO:mealpy.swarm_based.ACOR.OriginalACOR:>>>Problem: P, Epoch: 93, Current best: 0.0, Global best: 0.0, Runtime: 0.08511 seconds
# INFO:mealpy.swarm_based.ACOR.OriginalACOR:>>>Problem: P, Epoch: 94, Current best: 0.0, Global best: 0.0, Runtime: 0.08665 seconds
# INFO:mealpy.swarm_based.ACOR.OriginalACOR:>>>Problem: P, Epoch: 95, Current best: 0.0, Global best: 0.0, Runtime: 0.09198 seconds
# INFO:mealpy.swarm_based.ACOR.OriginalACOR:>>>Problem: P, Epoch: 96, Current best: 0.0, Global best: 0.0, Runtime: 0.08905 seconds
# INFO:mealpy.swarm_based.ACOR.OriginalACOR:>>>Problem: P, Epoch: 97, Current best: 0.0, Global best: 0.0, Runtime: 0.09968 seconds
# INFO:mealpy.swarm_based.ACOR.OriginalACOR:>>>Problem: P, Epoch: 98, Current best: 0.0, Global best: 0.0, Runtime: 0.08734 seconds
# INFO:mealpy.swarm_based.ACOR.OriginalACOR:>>>Problem: P, Epoch: 99, Current best: 0.0, Global best: 0.0, Runtime: 0.09448 seconds
# INFO:mealpy.swarm_based.ACOR.OriginalACOR:>>>Problem: P, Epoch: 100, Current best: 0.0, Global best: 0.0, Runtime: 0.08995 seconds
# Solution: [9. 7. 2. 6. 2. 3. 8. 5. 1. 3. 5. 7. 6. 7. 2. 6. 3. 3. 2. 1. 9. 5. 3. 5.
#  5. 9. 8. 8. 3. 8. 1. 2. 5. 1. 2. 2. 0. 2. 0. 9.], Fitness: 0.0
# Solution: [9. 7. 2. 6. 2. 3. 8. 5. 1. 3. 5. 7. 6. 7. 2. 6. 3. 3. 2. 1. 9. 5. 3. 5.
#  5. 9. 8. 8. 3. 8. 1. 2. 5. 1. 2. 2. 0. 2. 0. 9.], Fitness: 0.0

# %%
list=g_best.solution
s=np.round(g_best.solution, 0)
s = [str(int(i)) for i in s.tolist()]
exetime= end_time - start_time
print(exetime)
print(s)
data1 = {"name": s, "exetime": str(exetime)}

with open(f"ACOR_sample_{size}_{vmcount}.json", "w") as outfile:
  json.dump(data1, outfile,ensure_ascii=False, indent=4)
# Out:
# 11.850061416625977
# ['9', '7', '2', '6', '2', '3', '8', '5', '1', '3', '5', '7', '6', '7', '2', '6', '3', '3', '2', '1', '9', '5', '3', '5', '5', '9', '8', '8', '3', '8', '1', '2', '5', '1', '2', '2', '0', '2', '0', '9']
